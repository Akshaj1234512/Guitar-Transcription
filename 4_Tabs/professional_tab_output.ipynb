# %%
from professional_tab_renderer import (
    TabNote,              # Same structure!
    SVGTabRenderer,       # Replaces TabFormatter
    RenderConfig,         # New: configuration object
    jam_to_svg,          # Replaces jam_to_tab
    MusicLayout          # New: handles layout logic
)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 jam_to_svg(
#       2     jam=jam,
#       3     output_path='output.svg',
#       4     title="My Song",
#       5     tempo=120,
#       6     time_signature=(4, 4)
#       7 )
#       8 # Output is saved as SVG file
#
# File /data/colin-obrien/Music-AI/4_Tabs/professional_tab_renderer.py:499, in jam_to_svg(jam, output_path, title, tempo, time_signature, capo, config)
#     490             notes.append(TabNote(
#     491                 time=obs.time,
#     492                 string=val['string'],
#    (...)    495                 techniques=val.get('techniques', [])
#     496             ))
#     498 if not notes:
# --> 499     raise ValueError("No tablature data found in JAMS object.")
#     501 # Sort notes by time
#     502 notes.sort(key=lambda x: x.time)
#
# ...
